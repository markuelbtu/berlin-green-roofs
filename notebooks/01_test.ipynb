# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\Documents\Uni\Master_Bauing\WiSe25_26\AI_in_Human_Water\berlin-green-roofs\.venv\Scripts\python.exe

# %%
print(sys.version)
# Out:
# 3.13.5 (main, Jun 12 2025, 12:42:35) [MSC v.1943 64 bit (AMD64)]
